# %% [markdown]
# # Data Visualization Exercise

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips=sns.load_dataset("tips")
df=tips.copy()

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.nunique()
# Out:
# total_bill    229
# tip           123
# sex             2
# smoker          2
# day             4
# time            2
# size            6
# dtype: int64

# %%
df.isnull().any()
# Out:
# total_bill    False
# tip           False
# sex           False
# smoker        False
# day           False
# time          False
# size          False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
#BarPlot

# %%
df["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df["day"].value_counts().plot.bar()

# %%
df["day"].value_counts().plot.barh()

# %%
sns.barplot(x="day",y="total_bill",data=df)

# %%
sns.barplot(x="day",y="total_bill",hue="sex",data=df)

# %%
#CatPlot

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x="day",y="total_bill",data=df)

# %%
sns.catplot(x="day",y="total_bill",data=df,kind="swarm")

# %%
sns.catplot(x="day",y="total_bill",hue="time",data=df)

# %%
sns.catplot(x="day",y="total_bill",hue="time",data=df)

# %%
sns.catplot(x="day",y="total_bill",hue="time",data=df)

# %%
sns.catplot(x="day",y="total_bill",hue="time",col="sex",data=df)

# %%
sns.catplot(x="day",y="total_bill",hue="time",col="sex",row="smoker",data=df)

# %%
#DistPlot

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(df["total_bill"])

# %%
sns.distplot(df["total_bill"],kde=False)

# %%
sns.distplot(df["total_bill"],hist=False)

# %%
sns.kdeplot(df["total_bill"])

# %%
sns.kdeplot(df["total_bill"],shade=True)

# %%
sns.FacetGrid(df,hue="day").map(sns.kdeplot,"total_bill",shade=True)

# %%
sns.FacetGrid(df,hue="day",size=5).map(sns.kdeplot,"total_bill",shade=True)

# %%
sns.FacetGrid(df,hue="day",size=5).map(sns.kdeplot,"total_bill",shade=True).add_legend()

# %%
sns.FacetGrid(df,col="time",hue="day",size=5).map(sns.kdeplot,"total_bill",shade=True).add_legend()

# %%
#BoxPlot

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(y="tip",data=df)

# %%
sns.boxplot(x="time",y="total_bill",data=df)

# %%
sns.boxplot(x="time",y="total_bill",hue="sex",data=df)

# %%
sns.boxplot(x="size",y="total_bill",data=df)

# %%
sns.boxplot(x="sex",y="total_bill",data=df)

# %%
sns.boxplot(x="sex",y="size",data=df)

# %%
#PairPlot

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue="smoker")

# %%
sns.pairplot(df,vars=["total_bill","size"])

# %%
sns.pairplot(df,vars=["total_bill","size"],hue="smoker",size=5)

# %%
sns.pairplot(df,vars=["total_bill","size"],hue="smoker",size=5,kind="reg")

# %%
sns.pairplot(df,hue="time",kind="reg")

# %%
#Lineplot

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lineplot(x="size",y="total_bill",data=df)

# %%
sns.lineplot(x="size",y="total_bill",hue="sex",data=df)

# %%
sns.lineplot(x="size",y="total_bill",hue="sex",data=df,lw=3)

# %%
sns.lineplot(x="size",y="total_bill",hue="sex",data=df,lw=3,style="sex")
